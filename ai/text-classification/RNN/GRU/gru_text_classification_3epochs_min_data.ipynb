# %% [markdown]
# # RNN - GRU : 5 epochs and 0.5 of dataset

# %%
from common.text_classification_utils import *

dataset = load_dataset()

dataset
# Out:
#                                                       text  CORRECT  \
# 0                               zrkrwmgseetfegaozv kovx vh        0
# 1        Comment puis-je me rendre de l'aéroport de CHA...        1
# 2                               4f3;S0`HsL# hL8ydlwlM2cK7=        0
# 3                               u*]P\UsbAr,CoDnDdr*-GKN(0O        0
# 4        J'aimerais connaître le chemin pour aller de S...        1
# ...                                                    ...      ...
# 1302960                        Il a prétendu être mon ami.        0
# 1302961  I am planning a trip from saint paul les dax t...        0
# 1302962  Go from the train station of Loches to Venarey...        0
# 1302963  Je souhaiterais aller à verneuil sur serre dep...        1
# 1302964  Pourrais-tu m'indiquer comment aller de la vil...        1
#
#          NOT_FRENCH  NOT_TRIP  UNKNOWN
# 0                 0         0        1
# 1                 0         0        0
# 2                 0         0        1
# 3                 0         0        1
# 4                 0         0        0
# ...             ...       ...      ...
# 1302960           0         1        0
# 1302961           1         0        0
# 1302962           1         0        0
# 1302963           0         0        0
# 1302964           0         0        0
#
# [1302965 rows x 5 columns]

# %%
labels, id2label, label2id = prepare_labels(dataset)
# Out:
# ['CORRECT', 'NOT_FRENCH', 'NOT_TRIP', 'UNKNOWN']

# %%
show_labels_distribution(dataset, labels)

# %%
dataset = flatten_trips_labels(dataset)

show_labels_distribution(dataset, labels)

# %%
from sklearn.model_selection import train_test_split
# Shuffle train dataset, and pick 20% of it
dataset = dataset.sample(frac=0.2, random_state=0)
X_train = dataset['text']
y_train = dataset[labels]

# To check how vectorizer works without UNKNOWN words being isolated
X_train_without_unknown = dataset[dataset['UNKNOWN'] == 0]['text']
y_train_without_unknown = dataset[dataset['UNKNOWN'] == 0][labels]

# Split test dataset into 10% validation and 10% test
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

print(X_train.shape, X_test.shape, X_val.shape)
print(y_train.shape, y_test.shape, y_val.shape)
# Out:
# (208474,) (26059,) (26060,)
# (208474, 4) (26059, 4) (26060, 4)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Paramètres de tokenisation
vocab_size = 20000  # Choisissez une taille adaptée à votre vocabulaire
max_length = 100    # Longueur maximale des séquences

# Initialisation du tokenizer
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(X_train)

# Conversion des textes en séquences de tokens
X_train_sequences = tokenizer.texts_to_sequences(X_train)
X_test_sequences = tokenizer.texts_to_sequences(X_test)
X_val_sequences = tokenizer.texts_to_sequences(X_val)

# Padding des séquences pour qu'elles aient la même longueur
X_train_padded = pad_sequences(X_train_sequences, maxlen=max_length)
X_test_padded = pad_sequences(X_test_sequences, maxlen=max_length)
X_val_padded = pad_sequences(X_val_sequences, maxlen=max_length)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense

embedding_dim = 128
gru_units = 64

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_length))
model.add(GRU(gru_units))
model.add(Dense(4, activation='sigmoid'))  # Ajustez à 4 pour quatre labels

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 100, 128)          2560000
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 2,597,508
# Trainable params: 2,597,508
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 3
model.fit(X_train_padded, y_train, epochs=num_epochs, validation_data=(X_val_padded, y_val))
# Out:
# Epoch 1/5
# 6515/6515 [==============================] - 129s 19ms/step - loss: 0.0181 - accuracy: 0.8561 - val_loss: 0.0095 - val_accuracy: 0.9025
# Epoch 2/5
# 6515/6515 [==============================] - 127s 19ms/step - loss: 0.0035 - accuracy: 0.8754 - val_loss: 0.0050 - val_accuracy: 0.8571
# Epoch 3/5
# 6515/6515 [==============================] - 127s 20ms/step - loss: 0.0026 - accuracy: 0.8755 - val_loss: 0.0055 - val_accuracy: 0.8927
# Epoch 4/5
# 6515/6515 [==============================] - 128s 20ms/step - loss: 0.0023 - accuracy: 0.8952 - val_loss: 0.0050 - val_accuracy: 0.9239
# Epoch 5/5
# 6515/6515 [==============================] - 128s 20ms/step - loss: 0.0021 - accuracy: 0.9046 - val_loss: 0.0056 - val_accuracy: 0.9194

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test_padded)
threshold = 0.5
y_pred_binary = (y_pred > threshold).astype(int)

print(classification_report(y_test, y_pred_binary, target_names=labels))
# Out:
# 815/815 [==============================] - 8s 9ms/step
#               precision    recall  f1-score   support
#
#      CORRECT       1.00      1.00      1.00      7803
#   NOT_FRENCH       1.00      0.99      1.00      7730
#     NOT_TRIP       1.00      0.99      1.00      7786
#      UNKNOWN       0.99      1.00      1.00      7977
#
#    micro avg       1.00      1.00      1.00     31296
#    macro avg       1.00      1.00      1.00     31296
# weighted avg       1.00      1.00      1.00     31296
#  samples avg       1.00      1.00      1.00     31296
# C:\Users\nathp\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Distribution des labels dans l'ensemble d'entraînement :")
print(y_train.sum(axis=0))  # Somme pour chaque label dans y_train

print("\nDistribution des labels dans l'ensemble de test :")
print(y_test.sum(axis=0))   # Somme pour chaque label dans y_test
# Out:
# Distribution des labels dans l'ensemble d'entraînement :
# CORRECT       63013
# NOT_FRENCH    61779
# NOT_TRIP      62823
# UNKNOWN       62842
# dtype: int64
#
# Distribution des labels dans l'ensemble de test :
# CORRECT       7803
# NOT_FRENCH    7730
# NOT_TRIP      7786
# UNKNOWN       7977
# dtype: int64

# %%
from sklearn.metrics import classification_report
import numpy as np

for threshold in np.arange(0.1, 0.9, 0.1):
    y_pred_binary = (y_pred > threshold).astype(int)
    print(f"Seuil: {threshold}")
    print(classification_report(y_test, y_pred_binary, target_names=labels))
# Out:
# Seuil: 0.1
#               precision    recall  f1-score   support
#
#      CORRECT       1.00      1.00      1.00      7803
#   NOT_FRENCH       0.99      1.00      0.99      7730
#     NOT_TRIP       0.99      1.00      1.00      7786
#      UNKNOWN       0.99      1.00      1.00      7977
#
#    micro avg       0.99      1.00      1.00     31296
#    macro avg       0.99      1.00      1.00     31296
# weighted avg       0.99      1.00      1.00     31296
#  samples avg       1.00      1.00      1.00     31296
#
# Seuil: 0.2
#               precision    recall  f1-score   support
#
#      CORRECT       1.00      1.00      1.00      7803
#   NOT_FRENCH       1.00      1.00      1.00      7730
#     NOT_TRIP       1.00      1.00      1.00      7786
#      UNKNOWN       0.99      1.00      1.00      7977
#
#    micro avg       1.00      1.00      1.00     31296
#    macro avg       1.00      1.00      1.00     31296
# weighted avg       1.00      1.00      1.00     31296
#  samples avg       1.00      1.00      1.00     31296
#
# Seuil: 0.30000000000000004
#               precision    recall  f1-score   support
#
#      CORRECT       1.00      1.00      1.00      7803
#   NOT_FRENCH       1.00      1.00      1.00      7730
#     NOT_TRIP       1.00      0.99      1.00      7786
#      UNKNOWN       0.99      1.00      1.00      7977
#
#    micro avg       1.00      1.00      1.00     31296
#    macro avg       1.00      1.00      1.00     31296
# weighted avg       1.00      1.00      1.00     31296
#  samples avg       1.00      1.00      1.00     31296
#
# Seuil: 0.4
#               precision    recall  f1-score   support
#
#      CORRECT       1.00      1.00      1.00      7803
#   NOT_FRENCH       1.00      1.00      1.00      7730
#     NOT_TRIP       1.00      0.99      1.00      7786
#      UNKNOWN       0.99      1.00      1.00      7977
#
#    micro avg       1.00      1.00      1.00     31296
#    macro avg       1.00      1.00      1.00     31296
# weighted avg       1.00      1.00      1.00     31296
#  samples avg       1.00      1.00      1.00     31296
#
# Seuil: 0.5
#               precision    recall  f1-score   support
#
#      CORRECT       1.00      1.00      1.00      7803
#   NOT_FRENCH       1.00      0.99      1.00      7730
#     NOT_TRIP       1.00      0.99      1.00      7786
#      UNKNOWN       0.99      1.00      1.00      7977
#
#    micro avg       1.00      1.00      1.00     31296
#    macro avg       1.00      1.00      1.00     31296
# weighted avg       1.00      1.00      1.00     31296
#  samples avg       1.00      1.00      1.00     31296
#
# Seuil: 0.6
#               precision    recall  f1-score   support
#
#      CORRECT       1.00      1.00      1.00      7803
#   NOT_FRENCH       1.00      0.99      1.00      7730
#     NOT_TRIP       1.00      0.99      1.00      7786
#      UNKNOWN       1.00      1.00      1.00      7977
#
#    micro avg       1.00      1.00      1.00     31296
#    macro avg       1.00      1.00      1.00     31296
# weighted avg       1.00      1.00      1.00     31296
#  samples avg       1.00      1.00      1.00     31296
#
# Seuil: 0.7000000000000001
#               precision    recall  f1-score   support
#
#      CORRECT       1.00      1.00      1.00      7803
#   NOT_FRENCH       1.00      0.99      1.00      7730
#     NOT_TRIP       1.00      0.99      1.00      7786
#      UNKNOWN       1.00      1.00      1.00      7977
#
#    micro avg       1.00      1.00      1.00     31296
#    macro avg       1.00      1.00      1.00     31296
# weighted avg       1.00      1.00      1.00     31296
#  samples avg       1.00      1.00      1.00     31296
#
# Seuil: 0.8
#               precision    recall  f1-score   support
#
#      CORRECT       1.00      1.00      1.00      7803
#   NOT_FRENCH       1.00      0.99      1.00      7730
#     NOT_TRIP       1.00      0.99      1.00      7786
#      UNKNOWN       1.00      1.00      1.00      7977
#
#    micro avg       1.00      1.00      1.00     31296
#    macro avg       1.00      1.00      1.00     31296
# weighted avg       1.00      1.00      1.00     31296
#  samples avg       1.00      1.00      1.00     31296
# C:\Users\nathp\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\nathp\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\nathp\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\nathp\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
indices = np.random.choice(range(len(y_test)), 10, replace=False)  # Choisir 10 échantillons au hasard
for i in indices:
    print("Vrai label:", y_test.iloc[i].to_list())
    print("Prédiction:", y_pred_binary[i])
    print()
# Out:
# Vrai label: [0, 0, 0, 1]
# Prédiction: [0 0 0 1]
#
# Vrai label: [0, 0, 0, 1]
# Prédiction: [0 0 0 1]
#
# Vrai label: [1, 0, 0, 0]
# Prédiction: [1 0 0 0]
#
# Vrai label: [0, 0, 0, 1]
# Prédiction: [0 0 0 1]
#
# Vrai label: [0, 0, 0, 1]
# Prédiction: [0 0 0 1]
#
# Vrai label: [0, 1, 1, 0]
# Prédiction: [0 1 1 0]
#
# Vrai label: [0, 0, 0, 1]
# Prédiction: [0 0 0 1]
#
# Vrai label: [0, 0, 0, 1]
# Prédiction: [0 0 0 1]
#
# Vrai label: [1, 0, 0, 0]
# Prédiction: [1 0 0 0]
#
# Vrai label: [1, 0, 0, 0]
# Prédiction: [1 0 0 0]

# %%
show_confusion_matrix(y_pred, y_test, labels)

# %%
show_roc_curves(labels, y_pred, y_test)

# %%
new_texts = [
    "Je veux aller de Port-Boulet à Le Havre.",
    "Je veux aller de Port-Boulet au Havre.",
    "Je vais de Nantes à Paris.",
    "Je vais de Nantes à Nantes.",
    "Je veux aller de Nantes à Nantes.",
    "Je vais à Port-Boulet en partant de Le Havre",
    "Je vais à Port-Boulet en partant du Havre",
    "Peux-tu m'aider à trouver mon chemin vers Paris en partant d'Épierre ?",
    "Je cherche un moyen d'aller de Margny-Lès-Compiègne à Saarbrücken /Sarrebruck.",
    "Je veux me rendre chez mon ami Etienne à Saint-Étienne depuis Nantes.",
    "Je veux aller de la ville de Marseille à Tours.",
    "Recherche le chemin le plus court entre la ville de Lorient et Paris",
    "Trouve-moi un itinéraire pour aller à Besançon depuis la ville d'Oyonnax.",
    "Ca met combien de temps un Toulouse Paris ?",
    "C'est quoi le trajet de Troyes à Niort ?",
    "Comment aller à Niort depuis Troyes ?",
    "Comment aller à Niort depuis Troyes",
    "Recherche un itinéraire de Nantes à Paris où habite Théo",
    "Trouve-moi le chemin le plus rapide vers Paris depuis Nantes pour arriver chez Michel.",
    "Il y a-t-il des trains de Nantes à Montaigu"
]
new_texts_sequences = tokenizer.texts_to_sequences(new_texts)
new_texts_padded = pad_sequences(new_texts_sequences, maxlen=max_length)

predicted_labels = model.predict(new_texts_padded)

# Affichage des labels prédits
for i, text in enumerate(new_texts):
    print(f"Text: {text}")
    print("Predicted labels:")
    for j, label in enumerate(labels):
        print(f" - {label}: {round(predicted_labels[i][j] * 100, 2)}%")
# Out:
# 1/1 [==============================] - 0s 38ms/step
# Text: Je veux aller de Port-Boulet à Le Havre.
# Predicted labels:
#  - CORRECT: 99.96%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 3.96%
#  - UNKNOWN: 0.0%
# Text: Je veux aller de Port-Boulet au Havre.
# Predicted labels:
#  - CORRECT: 61.6%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 85.14%
#  - UNKNOWN: 0.04%
# Text: Je vais de Nantes à Paris.
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: Je vais de Nantes à Nantes.
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: Je veux aller de Nantes à Nantes.
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: Je vais à Port-Boulet en partant de Le Havre
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: Je vais à Port-Boulet en partant du Havre
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: Peux-tu m'aider à trouver mon chemin vers Paris en partant d'Épierre ?
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.01%
#  - UNKNOWN: 0.0%
# Text: Je cherche un moyen d'aller de Margny-Lès-Compiègne à Saarbrücken /Sarrebruck.
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: Je veux me rendre chez mon ami Etienne à Saint-Étienne depuis Nantes.
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: Je veux aller de la ville de Marseille à Tours.
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: Recherche le chemin le plus court entre la ville de Lorient et Paris
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: Trouve-moi un itinéraire pour aller à Besançon depuis la ville d'Oyonnax.
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: Ca met combien de temps un Toulouse Paris ?
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: C'est quoi le trajet de Troyes à Niort ?
# Predicted labels:
#  - CORRECT: 72.31%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 90.72%
#  - UNKNOWN: 0.0%
# Text: Comment aller à Niort depuis Troyes ?
# Predicted labels:
#  - CORRECT: 48.95%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 18.25%
#  - UNKNOWN: 0.1%
# Text: Comment aller à Niort depuis Troyes
# Predicted labels:
#  - CORRECT: 48.95%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 18.25%
#  - UNKNOWN: 0.1%
# Text: Recherche un itinéraire de Nantes à Paris où habite Théo
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.01%
#  - UNKNOWN: 0.0%
# Text: Trouve-moi le chemin le plus rapide vers Paris depuis Nantes pour arriver chez Michel.
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.0%
#  - UNKNOWN: 0.0%
# Text: Il y a-t-il des trains de Nantes à Montaigu
# Predicted labels:
#  - CORRECT: 100.0%
#  - NOT_FRENCH: 0.0%
#  - NOT_TRIP: 0.09%
#  - UNKNOWN: 0.0%
